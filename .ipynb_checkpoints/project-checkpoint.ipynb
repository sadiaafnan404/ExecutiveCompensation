# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

pd.set_option("display.max_columns", 120)
pd.set_option("display.width", 180)

# %%
DATA_PATH = Path("Dataset2.csv")  # adjust if needed
df = pd.read_csv(DATA_PATH)

def to_snake(s):
    return (str(s).strip()
            .replace(" ", "_").replace("-", "_").replace("/", "_").replace(".", "_")
            .lower())

df.columns = [to_snake(c) for c in df.columns]
df["enddate"] = pd.to_datetime(df["enddate"], errors="coerce")

# %%
schema = pd.DataFrame({
    "column": df.columns,
    "dtype": [str(dt) for dt in df.dtypes],
    "non_null": df.notna().sum().values,
    "nulls": df.isna().sum().values,
    "unique": [df[c].nunique(dropna=True) for c in df.columns],
})
schema.to_csv("data_dictionary.csv", index=False)
schema.head(20)
# Out:
#                           column           dtype  non_null  nulls  unique
# 0                          stock          object     17511      0    4422
# 1                        enddate  datetime64[ns]     17511      0     255
# 2                accountspayable         float64     16415   1096   14819
# 3                      inventory         float64      9640   7871    8867
# 4                   longtermdebt         float64     11222   6289   10746
# 5                 netreceivables         float64     14544   2967   13691
# 6              nettangibleassets         float64     17351    160   17089
# 7            longterminvestments         float64      7499  10012    6874
# 8             totalcurrentassets         float64     17331    180   16999
# 9         propertyplantequipment         float64     15768   1743   14905
# 10        otherstockholderequity         float64     12046   5465    9878
# 11  deferredlongtermassetcharges         float64      6055  11456    5215
# 12       totalcurrentliabilities         float64     17316    195   16830
# 13                          cash         float64     16929    582   15816
# 14                   otherassets         float64     15863   1648   13772
# 15                 treasurystock         float64     12972   4539   11239
# 16                      goodwill         float64      9663   7848    7307
# 17                     otherliab         float64     14222   3289   13079
# 18              retainedearnings         float64     16091   1420   15882
# 19            othercurrentassets         float64     11209   6302    9404

# %%
df = (df
      .drop_duplicates(subset=["stock", "enddate"])
      .sort_values(["stock", "enddate"])
      .reset_index(drop=True))
df.shape
# Out:
# (17511, 31)

# %%
to_float = lambda s: pd.to_numeric(df[s], errors="coerce").astype(float)

assets  = to_float("totalassets")
liab    = to_float("totalliab")
equity  = to_float("totalstockholderequity")
c_assets= to_float("totalcurrentassets")
c_liab  = to_float("totalcurrentliabilities")
inv     = to_float("inventory")
cash    = to_float("cash")
recv    = to_float("netreceivables")
ppe     = to_float("propertyplantequipment")
intang  = to_float("intangibleassets")
re      = to_float("retainedearnings")

def safe_div(n, d):
    return np.where((d==0) | pd.isna(d), np.nan, n/d)

# %%
df["year"] = df["enddate"].dt.year

df["leverage"]                     = safe_div(liab, assets)
df["equity_to_assets"]             = safe_div(equity, assets)
df["current_ratio"]                = safe_div(c_assets, c_liab)
df["quick_ratio"]                  = safe_div(c_assets - inv, c_liab)
df["wc_to_assets"]                 = safe_div(c_assets - c_liab, assets)
df["cash_to_assets"]               = safe_div(cash, assets)
df["receivables_to_assets"]        = safe_div(recv, assets)
df["inventory_to_assets"]          = safe_div(inv, assets)
df["ppe_to_assets"]                = safe_div(ppe, assets)
df["intangibles_to_assets"]        = safe_div(intang, assets)
df["retained_earnings_to_assets"]  = safe_div(re, assets)

# %%
# Key: use fill_method=None to avoid deprecated default behavior
df["asset_growth"] = (
    df.groupby("stock", sort=True)["totalassets"]
      .pct_change(fill_method=None)
      .astype(float)
)

# %%
metrics = [
    "leverage","equity_to_assets","current_ratio","quick_ratio","wc_to_assets",
    "cash_to_assets","receivables_to_assets","inventory_to_assets","ppe_to_assets",
    "intangibles_to_assets","retained_earnings_to_assets","asset_growth"
]

wins = df.copy()
for m in metrics:
    s = pd.to_numeric(wins[m], errors="coerce")
    lo, hi = np.nanpercentile(s.dropna(), [1, 99])
    wins[m] = s.clip(lo, hi)

wins.shape
# Out:
# (17511, 44)

# %%
summary = wins[metrics].describe(percentiles=[.01,.05,.25,.5,.75,.95,.99]).T
summary["non_null"] = wins[metrics].notna().sum().values
summary.to_csv("summary_stats.csv")
corr = wins[metrics].corr(method="pearson", min_periods=100)
corr.to_csv("correlation_matrix.csv")
summary.head(12), corr.round(2)
# Out:
# (                               count      mean       std        min         1%        5%       25%       50%       75%        95%        99%        max  non_null
#  leverage                     17315.0  0.580853  0.334966   0.017042   0.017046  0.102214  0.353801  0.560314  0.783372   1.037811   2.093732   2.094994     17315
#  equity_to_assets             17339.0  0.350301  0.484453  -2.489655  -2.489338 -0.259357  0.169204  0.404006  0.623899   0.889094   0.984621   0.984708     17339
#  current_ratio                17305.0  3.162214  4.758293   0.025990   0.025991  0.059886  0.951008  1.734745  3.247870  11.260169  32.490399  32.490905     17305
#  quick_ratio                   9636.0  1.657489  1.730533   0.025098   0.025104  0.047007  0.650344  1.177431  1.987166   5.284532   9.879481   9.887085      9636
#  wc_to_assets                 17305.0  0.135523  0.406611  -0.864855  -0.864845 -0.791558 -0.006425  0.122942  0.367928   0.807012   0.929759   0.929768     17305
#  cash_to_assets               16929.0  0.164026  0.221381   0.000372   0.000373  0.003219  0.022548  0.072933  0.201295   0.728215   0.965154   0.965182     16929
#  receivables_to_assets        14544.0  0.116544  0.126950   0.000731   0.000733  0.004136  0.027010  0.080083  0.158504   0.366612   0.721550   0.722137     14544
#  inventory_to_assets           9640.0  0.109130  0.127041   0.000064   0.000064  0.000470  0.010783  0.068203  0.157789   0.370648   0.627005   0.627019      9640
#  ppe_to_assets                15768.0  0.236208  0.274547   0.000973   0.000973  0.004641  0.029381  0.111300  0.350359   0.856504   0.940808   0.940825     15768
#  intangibles_to_assets        11238.0  0.092610  0.116847   0.000215   0.000215  0.001024  0.010324  0.045933  0.132411   0.330205   0.602902   0.603357     11238
#  retained_earnings_to_assets  16076.0 -1.024604  3.485473 -23.604824 -23.597854 -6.411711 -0.605916  0.021850  0.219092   0.675708   1.097730   1.098524     16076
#  asset_growth                 12961.0  0.242175  0.775656  -0.529439  -0.529236 -0.250190 -0.021060  0.057721  0.204053   1.201158   5.659437   5.689979     12961,
#                               leverage  equity_to_assets  current_ratio  quick_ratio  wc_to_assets  cash_to_assets  receivables_to_assets  inventory_to_assets  ppe_to_assets  \
#  leverage                         1.00             -0.76          -0.37        -0.50         -0.53           -0.19                   0.12                -0.13          -0.02
#  equity_to_assets                -0.76              1.00           0.22         0.37          0.33           -0.06                  -0.09                 0.10           0.05
#  current_ratio                   -0.37              0.22           1.00         0.87          0.58            0.36                   0.13                 0.23          -0.14
#  quick_ratio                     -0.50              0.37           0.87         1.00          0.65            0.52                   0.01                -0.03          -0.12
#  wc_to_assets                    -0.53              0.33           0.58         0.65          1.00            0.51                   0.24                 0.43          -0.10
#  cash_to_assets                  -0.19             -0.06           0.36         0.52          0.51            1.00                  -0.05                 0.00          -0.30
#  receivables_to_assets            0.12             -0.09           0.13         0.01          0.24           -0.05                   1.00                 0.19          -0.31
#  inventory_to_assets             -0.13              0.10           0.23        -0.03          0.43            0.00                   0.19                 1.00          -0.14
#  ppe_to_assets                   -0.02              0.05          -0.14        -0.12         -0.10           -0.30                  -0.31                -0.14           1.00
#  intangibles_to_assets           -0.03              0.03          -0.04        -0.02          0.07           -0.09                  -0.12                -0.07          -0.20
#  retained_earnings_to_assets     -0.17              0.27          -0.05        -0.06         -0.08           -0.42                   0.02                -0.00           0.09
#  asset_growth                    -0.13              0.01           0.25         0.17          0.19            0.28                  -0.04                -0.04          -0.11
#
#                               intangibles_to_assets  retained_earnings_to_assets  asset_growth
#  leverage                                     -0.03                        -0.17         -0.13
#  equity_to_assets                              0.03                         0.27          0.01
#  current_ratio                                -0.04                        -0.05          0.25
#  quick_ratio                                  -0.02                        -0.06          0.17
#  wc_to_assets                                  0.07                        -0.08          0.19
#  cash_to_assets                               -0.09                        -0.42          0.28
#  receivables_to_assets                        -0.12                         0.02         -0.04
#  inventory_to_assets                          -0.07                        -0.00         -0.04
#  ppe_to_assets                                -0.20                         0.09         -0.11
#  intangibles_to_assets                         1.00                        -0.04          0.05
#  retained_earnings_to_assets                  -0.04                         1.00          0.00
#  asset_growth                                  0.05                         0.00          1.00  )

# %%
wins.to_csv("Dataset2_cleaned.csv", index=False)

# %%
import matplotlib.pyplot as plt
Path("figures").mkdir(exist_ok=True)

plt.figure()
wins["leverage"].dropna().plot(kind="hist", bins=50, title="Distribution of Leverage (Debt/Assets)")
plt.xlabel("Leverage (Debt/Assets)")
plt.savefig("figures/hist_leverage.png", bbox_inches="tight")
plt.close()

plt.figure()
wins["asset_growth"].dropna().plot(kind="hist", bins=50, title="Distribution of Asset Growth (YoY)")
plt.xlabel("Asset Growth (YoY)")
plt.savefig("figures/hist_asset_growth.png", bbox_inches="tight")
plt.close()

avg_lev = wins.groupby("year", as_index=True)["leverage"].mean()
plt.figure()
avg_lev.plot(kind="line", marker="o", title="Average Leverage by Year")
plt.xlabel("Year"); plt.ylabel("Average Leverage")
plt.savefig("figures/avg_leverage_by_year.png", bbox_inches="tight")
plt.close()

# %%
import matplotlib.pyplot as plt
from pathlib import Path

Path("figures").mkdir(exist_ok=True)

# Histogram: Leverage
plt.figure()
wins["leverage"].dropna().plot(kind="hist", bins=50, title="Distribution of Leverage (Debt/Assets)")
plt.xlabel("Leverage (Debt/Assets)")
plt.savefig("figures/hist_leverage.png", bbox_inches="tight")
plt.show()   # 👈 displays in notebook

# Histogram: Asset Growth
plt.figure()
wins["asset_growth"].dropna().plot(kind="hist", bins=50, title="Distribution of Asset Growth (YoY)")
plt.xlabel("Asset Growth (YoY)")
plt.savefig("figures/hist_asset_growth.png", bbox_inches="tight")
plt.show()

# Trend: Average Leverage by Year
avg_lev = wins.groupby("year", as_index=True)["leverage"].mean()
plt.figure()
avg_lev.plot(kind="line", marker="o", title="Average Leverage by Year")
plt.xlabel("Year"); plt.ylabel("Average Leverage")
plt.savefig("figures/avg_leverage_by_year.png", bbox_inches="tight")
plt.show()

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
import os

# load cleaned if present; else raw
try:
    df = pd.read_csv("Dataset2_cleaned.csv")
except FileNotFoundError:
    df = pd.read_csv("Dataset2.csv")

# make sure figures folder exists
os.makedirs("figures", exist_ok=True)

# log-transform total assets
s = df['totalassets'].dropna()
s = s[s > 0]
ln_assets = np.log(s)

plt.figure()
plt.hist(ln_assets, bins=50, edgecolor="black")
plt.title("Distribution of Total Assets (log-transformed)")
plt.xlabel("Log of Total Assets")
plt.ylabel("Frequency")

# export both to working dir and figures folder
plt.savefig("Figure1_TotalAssets_LogDist.png", dpi=300, bbox_inches="tight")
plt.savefig("figures/Figure1_TotalAssets_LogDist.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt
import os

# make sure figures folder exists
os.makedirs("figures", exist_ok=True)

# drop NA and filter non-negative leverage values
s = df['leverage'].dropna()
s = s[s >= 0]

plt.figure()
plt.hist(s, bins=50, edgecolor="black")
plt.title("Distribution of Leverage (Debt/Assets)")
plt.xlabel("Leverage Ratio")
plt.ylabel("Frequency")

# save figure
plt.savefig("Figure2_Leverage_Distribution.png", dpi=300, bbox_inches="tight")
plt.savefig("figures/Figure2_Leverage_Distribution.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt
import os

# Make sure figures folder exists
os.makedirs("figures", exist_ok=True)

# Drop missing values for both variables
df_scatter = df[['leverage', 'equity_to_assets']].dropna()

plt.figure(figsize=(7,5))
plt.scatter(df_scatter['leverage'], df_scatter['equity_to_assets'], 
            alpha=0.5, s=10, edgecolors='none')

plt.title("Leverage vs Equity-to-Assets")
plt.xlabel("Leverage (Debt/Assets)")
plt.ylabel("Equity-to-Assets")

# Save figure
plt.savefig("Figure4_Leverage_vs_Equity.png", dpi=300, bbox_inches="tight")
plt.savefig("figures/Figure4_Leverage_vs_Equity.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt
import os

# make sure figures folder exists
os.makedirs("figures", exist_ok=True)

# group by year and calculate average current ratio
avg_current_ratio = df.groupby('year')['current_ratio'].mean()

plt.figure(figsize=(8,5))
avg_current_ratio.plot(kind='line', marker='o')

plt.title("Average Current Ratio by Year")
plt.xlabel("Year")
plt.ylabel("Average Current Ratio")
plt.grid(True)

# save figure
plt.savefig("Figure6_AvgCurrentRatio_ByYear.png", dpi=300, bbox_inches="tight")
plt.savefig("figures/Figure6_AvgCurrentRatio_ByYear.png", dpi=300, bbox_inches="tight")
plt.show()
