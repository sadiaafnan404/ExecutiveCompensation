# %%
pip install pandas numpy matplotlib seaborn statsmodels linearmodels
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.13/site-packages (2.1.3)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.13/site-packages (3.10.0)
# Requirement already satisfied: seaborn in /opt/anaconda3/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: statsmodels in /opt/anaconda3/lib/python3.13/site-packages (0.14.4)
# Requirement already satisfied: linearmodels in /opt/anaconda3/lib/python3.13/site-packages (6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /opt/anaconda3/lib/python3.13/site-packages (from statsmodels) (1.15.3)
# Requirement already satisfied: patsy>=0.5.6 in /opt/anaconda3/lib/python3.13/site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: mypy-extensions>=0.4 in /opt/anaconda3/lib/python3.13/site-packages (from linearmodels) (1.0.0)
# Requirement already satisfied: Cython>=3.0.10 in /opt/anaconda3/lib/python3.13/site-packages (from linearmodels) (3.1.3)
# Requirement already satisfied: pyhdfe>=0.1 in /opt/anaconda3/lib/python3.13/site-packages (from linearmodels) (0.2.0)
# Requirement already satisfied: formulaic>=1.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from linearmodels) (1.2.0)
# Requirement already satisfied: setuptools-scm<9.0.0,>=8.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (8.3.1)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.13/site-packages (from setuptools-scm<9.0.0,>=8.0.0->setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (72.1.0)
# Requirement already satisfied: interface-meta>=1.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from formulaic>=1.0.0->linearmodels) (1.3.0)
# Requirement already satisfied: narwhals>=1.17 in /opt/anaconda3/lib/python3.13/site-packages (from formulaic>=1.0.0->linearmodels) (1.31.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from formulaic>=1.0.0->linearmodels) (4.12.2)
# Requirement already satisfied: wrapt>=1.17.0rc1 in /opt/anaconda3/lib/python3.13/site-packages (from formulaic>=1.0.0->linearmodels) (1.17.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Load the dataset (make sure the CSV is in the same folder as your notebook)
df = pd.read_csv("Dataset2.csv")

# Inspect the first 5 rows
print(df.head())

# Check shape (rows, columns)
print(df.shape)

# Quick info on columns & datatypes
print(df.info())
# Out:
#   stock     endDate  accountsPayable    inventory  longTermDebt  \
# 0   IVC  2019-12-31       88003000.0  121184000.0   219464000.0
# 1   IVC  2018-12-31       92469000.0  128644000.0   225733000.0
# 2   IVC  2017-12-31       90566000.0  121933000.0   241405000.0
# 3   IVC  2016-12-31       88236000.0  135644000.0   146088000.0
# 4  CSLT  2019-12-31       19596000.0          NaN           NaN
#
#    netReceivables  netTangibleAssets  longTermInvestments  totalCurrentAssets  \
# 0     140013000.0        -91334000.0              85000.0         355877000.0
# 1     138476000.0        -48632000.0              90000.0         397410000.0
# 2     143464000.0         -8233000.0             103000.0         456914000.0
# 3     132707000.0         32762000.0             108000.0         409072000.0
# 4      31397000.0         68911000.0                  NaN          95470000.0
#
#    propertyPlantEquipment  ...   totalAssets  otherCurrentLiab  \
# 0              92183000.0  ...  8.521260e+08        21634000.0
# 1              74306000.0  ...  8.858550e+08        22750000.0
# 2              80016000.0  ...  1.066033e+09        34119000.0
# 3              75359000.0  ...  9.037430e+08        33800000.0
# 4              18762000.0  ...  2.427840e+08        18768000.0
#
#    deferredLongTermLiab  totalStockholderEquity    totalLiab  capitalSurplus  \
# 0              602000.0             308516000.0  543610000.0     312650000.0
# 1              402000.0             359147000.0  526708000.0     297919000.0
# 2              787000.0             423294000.0  642739000.0     290125000.0
# 3              793000.0             422387000.0  481356000.0     266151000.0
# 4            21429000.0             172874000.0   69910000.0     627899000.0
#
#    intangibleAssets  shortTermInvestments  shortLongTermDebt  minorityInterest
# 0        26447000.0                   NaN                NaN               NaN
# 1        26506000.0                   NaN                NaN               NaN
# 2        30244000.0                   NaN                NaN               NaN
# 3        29023000.0                   NaN                NaN               NaN
# 4               NaN            16411000.0                NaN               NaN
#
# [5 rows x 31 columns]
# (17511, 31)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17511 entries, 0 to 17510
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   stock                         17511 non-null  object
#  1   endDate                       17511 non-null  object
#  2   accountsPayable               16415 non-null  float64
#  3   inventory                     9640 non-null   float64
#  4   longTermDebt                  11222 non-null  float64
#  5   netReceivables                14544 non-null  float64
#  6   netTangibleAssets             17351 non-null  float64
#  7   longTermInvestments           7499 non-null   float64
#  8   totalCurrentAssets            17331 non-null  float64
#  9   propertyPlantEquipment        15768 non-null  float64
#  10  otherStockholderEquity        12046 non-null  float64
#  11  deferredLongTermAssetCharges  6055 non-null   float64
#  12  totalCurrentLiabilities       17316 non-null  float64
#  13  cash                          16929 non-null  float64
#  14  otherAssets                   15863 non-null  float64
#  15  treasuryStock                 12972 non-null  float64
#  16  goodWill                      9663 non-null   float64
#  17  otherLiab                     14222 non-null  float64
#  18  retainedEarnings              16091 non-null  float64
#  19  otherCurrentAssets            11209 non-null  float64
#  20  commonStock                   16329 non-null  float64
#  21  totalAssets                   17339 non-null  float64
#  22  otherCurrentLiab              13304 non-null  float64
#  23  deferredLongTermLiab          2632 non-null   float64
#  24  totalStockholderEquity        17354 non-null  float64
#  25  totalLiab                     17326 non-null  float64
#  26  capitalSurplus                14489 non-null  float64
#  27  intangibleAssets              11238 non-null  float64
#  28  shortTermInvestments          3858 non-null   float64
#  29  shortLongTermDebt             5435 non-null   float64
#  30  minorityInterest              4405 non-null   float64
# dtypes: float64(29), object(2)
# memory usage: 4.1+ MB
# None
